# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\faiza\\Music\\Project\\eKYC'

# %%
base_dir = os.path.join('data', '01_raw_data')
filename1 = "srk1.jpeg"
filename2 = "srk2.webp"
img_path1 = os.path.join(base_dir, filename1)
img_path2 = os.path.join(base_dir, filename2)

print(f"Image Path 1: {img_path1} - Exists: {os.path.exists(img_path1)}")
print(f"Image Path 2: {img_path2} - Exists: {os.path.exists(img_path2)}")
# Out:
# Image Path 1: data\01_raw_data\srk1.jpeg - Exists: True
# Image Path 2: data\01_raw_data\srk2.webp - Exists: True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread(img_path2, cv2.IMREAD_GRAYSCALE)

# Display the image
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# Perform a basic operation (e.g., invert the image)
inverted_image = 255 - image

inverted_image
# Out:
# array([[137, 137, 136, ...,  61,  60,  60],
#        [137, 137, 136, ...,  61,  60,  60],
#        [137, 137, 136, ...,  61,  60,  60],
#        ...,
#        [212, 212, 211, ...,  40,  40,  40],
#        [212, 212, 211, ...,  40,  40,  40],
#        [212, 212, 211, ...,  40,  40,  40]], dtype=uint8)

# %%
image
# Out:
# array([[118, 118, 119, ..., 194, 195, 195],
#        [118, 118, 119, ..., 194, 195, 195],
#        [118, 118, 119, ..., 194, 195, 195],
#        ...,
#        [ 43,  43,  44, ..., 215, 215, 215],
#        [ 43,  43,  44, ..., 215, 215, 215],
#        [ 43,  43,  44, ..., 215, 215, 215]], dtype=uint8)

# %%
# 2-dimensional as only x and y coordinates
image.shape
# Out:
# (1200, 1200)

# %%
# Image with RGB channels
image = cv2.imread(img_path2)

colorImg=cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Display the image

plt.imshow(colorImg)
plt.axis('off')
plt.show()

# %%
# RGB
colorImg.shape
# Out:
# (1200, 1200, 3)

# %%
# Perform a basic operation (e.g., invert the image)

inverted_image_RGB = 255 - colorImg

inverted_image
# Out:
# array([[137, 137, 136, ...,  61,  60,  60],
#        [137, 137, 136, ...,  61,  60,  60],
#        [137, 137, 136, ...,  61,  60,  60],
#        ...,
#        [212, 212, 211, ...,  40,  40,  40],
#        [212, 212, 211, ...,  40,  40,  40],
#        [212, 212, 211, ...,  40,  40,  40]], dtype=uint8)
